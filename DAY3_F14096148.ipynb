# %%
import numpy as np
import random
import pandas as pd

# %%
#codeshare line #197-#239
def fevalM(Q,q,x):
    y=x.transpose().dot(Q).dot(x)/2+q.transpose().dot(x)
    return y

def gfevalM(Q,q,x):
    y=-Q.dot(x)-q
    return y

iterationNo=[]
iterationX1=[]
iterationX2=[]
iterationX3=[]
iterationX4=[]
iterationX5=[]

#x0,x1,k=0,10,1
x=np.array([[0],[0],[0]])
k=1

#d0,d1=gfeval(x0,x1)
Q=np.array([[4,3,0],[3,4,-1],[0,-1,4]])
q=np.array([[-24],[-30],[24]])
d=gfevalM(Q,q,x)
r=gfevalM(Q,q,x)
# print(r)

#norm_d=np.sqrt(d0*d0+d1*d1)

while True:
    iterationNo.append(k)
    iterationX1.append(x[0,0])
    iterationX2.append(x[1,0])
    iterationX3.append(x[2,0])
    iterationX4.append(np.sqrt(r.transpose().dot(r))[0,0])
    iterationX5.append(fevalM(Q,q,x)[0,0])
    
    if np.sqrt(r.transpose().dot(r)) <0.0000001 and k>=2:
        break
    

    t=(d.transpose().dot(r))/(d.transpose().dot(Q).dot(d))
    
    x=x+t*d
        

    r_old = r
    
    r=r-t*Q.dot(d)
    
    s=(r.transpose().dot(r))/(r_old.transpose().dot(r_old))
    
    d=r+s*d
    
#     print('k=%d' % k,x[0,0],x[1,0],x[2,0],fevalM(Q,q,x)[0,0])#page 32, k=1
    
    k=k+1
    
    
Table={"k":iterationNo,"$x^{0}$":iterationX1,"$x^{1}$":iterationX2,"$x^{2}$":iterationX3,"norm_r":iterationX4,"fvalue":iterationX5}
pd.DataFrame(Table)
# Out:
#    k   $x^{0}$   $x^{1}$   $x^{2}$        norm_r      fvalue
# 0  1  0.000000  0.000000  0.000000  4.529901e+01    0.000000
# 1  2  3.525773  4.407216 -3.525773  6.647578e+00 -150.726804
# 2  3  2.858011  4.148972 -4.954222  1.767135e-01 -155.981379
# 3  4  3.000000  4.000000 -5.000000  2.531175e-15 -156.000000

# %% [markdown]
# <p style="color:blue">Since
# $$
# \begin{array}{l}
# \displaystyle\frac{\partial }{\partial x_1}f(x)  =  1-\displaystyle\frac{1}{x_1}+\frac{1}{5-\sum_{i=1}^{4}x_i}\\
# \displaystyle\frac{\partial }{\partial x_2}f(x)  =  -0.6-\displaystyle\frac{1}{x_2}+\frac{1}{5-\sum_{i=1}^{4}x_i}\\
# \displaystyle\frac{\partial }{\partial x_3}f(x)  =  4-\displaystyle\frac{1}{x_3}+\frac{1}{5-\sum_{i=1}^{4}x_i}\\
# \displaystyle\frac{\partial }{\partial x_4}f(x)  =  0.25-\displaystyle\frac{1}{x_4}+\frac{1}{5-\sum_{i=1}^{4}x_i}\\
# \end{array},
# $$
# we obtain
# $$
# \begin{array}{rcl}
# \displaystyle\frac{\partial }{\partial x_1}\frac{\partial }{\partial x_1}f(x)  &= & \displaystyle\frac{\partial }{\partial x_1}\left(1-\frac{1}{x_1}+\frac{1}{5-\sum_{i=1}^{4}x_i}\right) \\
# &=& \displaystyle-\frac{-1}{(x_1)^2}+\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\frac{\partial}{\partial x_1} \left(5-\sum_{i=1}^{4}x_i\right)\\
# &=& \displaystyle\frac{1}{(x_1)^2}+\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}(-1)=\frac{1}{(x_1)^2}+\frac{1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\\
# \displaystyle\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_1}f(x)  &= & \displaystyle\frac{\partial }{\partial x_2}\left(1-\frac{1}{x_1}+\frac{1}{5-\sum_{i=1}^{4}x_i}\right) \\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\frac{\partial}{\partial x_2} \left(5-\sum_{i=1}^{4}x_i\right)\\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}(-1)=\frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \displaystyle\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_1}f(x)  &= & \displaystyle\frac{\partial }{\partial x_3}\left(1-\frac{1}{x_1}+\frac{1}{5-\sum_{i=1}^{4}x_i}\right) \\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\frac{\partial}{\partial x_3} \left(5-\sum_{i=1}^{4}x_i\right)\\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}(-1)=\frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \displaystyle\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_1}f(x)  &= & \displaystyle\frac{\partial }{\partial x_4}\left(1-\frac{1}{x_1}+\frac{1}{5-\sum_{i=1}^{4}x_i}\right) \\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\frac{\partial}{\partial x_4} \left(5-\sum_{i=1}^{4}x_i\right)\\
# &=& \displaystyle\frac{-1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}(-1)=\frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \end{array}
# $$
# Similarily,
# $$
# \begin{array}{l}
# \displaystyle\frac{\partial }{\partial x_1}\frac{\partial }{\partial x_2}f(x)
# =\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_2}f(x)
# =\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_2}f(x)\\
# =\displaystyle\frac{\partial }{\partial x_1}\frac{\partial }{\partial x_3}f(x)
# =\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_3}f(x)
# =\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_3}f(x)\\
# =\displaystyle\frac{\partial }{\partial x_1}\frac{\partial }{\partial x_4}f(x)
# =\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_4}f(x)
# =\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_4}f(x)\\
# =\displaystyle\frac{1}{(5-\sum_{i=1}^{4}x_i)^2}
# \end{array}
# $$
# and
# $$
# \begin{array}{l}
# \displaystyle\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_2}f(x)=\frac{1}{(x_2)^2}+\frac{1}{\left(5-\sum_{i=1}^{4}x_i\right)^2} \\
# \displaystyle\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_3}f(x)=\frac{1}{(x_3)^2}+\frac{1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\\
# \displaystyle\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_4}f(x)=\frac{1}{(x_4)^2}+\frac{1}{\left(5-\sum_{i=1}^{4}x_i\right)^2}\\
# \end{array}
# $$
# Therefore, we can obtain the hessian matrix $H$ by
# $$
# H=
# \left[
# \begin{array}{cccc}
# \frac{\partial }{\partial x_1}\frac{\partial }{\partial x_1}f(x)&\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_1}f(x)&\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_1}f(x)&\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_1}f(x)\\
# \frac{\partial }{\partial x_1}\frac{\partial }{\partial x_2}f(x)&\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_2}f(x)&\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_2}f(x)&\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_2}f(x)\\
# \frac{\partial }{\partial x_1}\frac{\partial }{\partial x_3}f(x)&\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_3}f(x)&\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_3}f(x)&\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_3}f(x)\\
# \frac{\partial }{\partial x_1}\frac{\partial }{\partial x_4}f(x)&\frac{\partial }{\partial x_2}\frac{\partial }{\partial x_4}f(x)&\frac{\partial }{\partial x_3}\frac{\partial }{\partial x_4}f(x)&\frac{\partial }{\partial x_4}\frac{\partial }{\partial x_4}f(x)\\
# \end{array}
# \right]
# $$
# $$
# =
# \left[
# \begin{array}{cccc}
# \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2} & \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2} & \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2} & \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}& \frac{1}{(5-\sum_{i=1}^{4}x_i)^2} & \frac{1}{(5-\sum_{i=1}^{4}x_i)^2}\\
# \end{array}
# \right]+
# \left[
# \begin{array}{cccc}
# \frac{1}{(x_1)^2}&0 &0 &0\\
# 0&\frac{1}{(x_2)^2}&0&0\\
# 0&0&\frac{1}{(x_3)^2}&0\\
# 0&0&0&\frac{1}{(x_4)^2}\\
# \end{array}
# \right]
# $$</p>

# %%
def H(x):
    a=[[1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2]]
    b=[[1/x[0,0]**2,0,0,0],[0,1/x[1,0]**2,0,0],[0,0,1/x[2,0]**2,0],[0,0,0,1/x[3,0]**2]]
    y=np.add(a,b)
    return y

H(np.array([[1],[1],[1],[1]]))
# Out:
# array([[2., 1., 1., 1.],
#        [1., 2., 1., 1.],
#        [1., 1., 2., 1.],
#        [1., 1., 1., 2.]])

# %%
#codeshare line #197-#239
def feval(x):
    y=1*x[0,0]+(-0.6)*x[1,0]+4*x[2,0]+0.25*x[3,0]
    y=y-np.log(x[0,0])-np.log(x[1,0])-np.log(x[2,0])-np.log(x[3,0])
    y=y-np.log(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y
def gfeval(x):
    y=np.array([[0.],[2.],[3.],[4.]])
    y[0,0]=1-1/(x[0,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[1,0]=0-0.6-1/(x[1,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[2,0]=4-1/(x[2,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[3,0]=0.25-1/(x[3,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y

iterationNo=[]
iterationX1=[]
iterationX2=[]
iterationX3=[]
iterationX4=[]
iterationX5=[]
iterationX6=[]
iterationX7=[]

#x0,x1,k=0,10,1
x=np.array([[1],[1],[1],[1]])
k=1

#d0,d1=gfeval(x0,x1)
r=gfeval(x)
d=r


while np.sqrt(d.transpose().dot(d)) > 0.000001:
    print('k=%d' % k,x[0,0],x[1,0],x[2,0],x[3,0],feval(x))
    t=(r.transpose().dot(d))/(d.transpose().dot(H(x)).dot(d))
    x=x+t*d
    
    r=gfeval(x)
    s=-(d.transpose().dot(H(x).transpose().dot(r)))/(d.transpose().dot(H(x).transpose().dot(d)))
    
    d=r+s*d
    
    k=k+1
    
#    print('k=%d' % k,x0,x1,d0,d1,norm_d,alpha,feval(x0,x1))#page 32, k=1

#     iterationNo.append(k)
#     iterationX1.append(x[0,0])
#     iterationX2.append(x[1,0])
#     iterationX3.append(d[0,0])
#     iterationX4.append(d[1,0])
#     iterationX5.append(norm_dM[0,0])
#     iterationX6.append(alphaM[0,0])
#     iterationX7.append(fevalM(Q,q,b,x)[0,0])
    
    
    
Table={"k":iterationNo,"$x_{0}$":iterationX1,"$x^{1}$":iterationX2,"$d^{0}$":iterationX3,"$d^{1}$":iterationX4,"norm_d":iterationX5,"alpha":iterationX6,"fvalue":iterationX7,}
pd.DataFrame(Table)
# Out:
# k=1 1 1 1 1 4.65
# k=2 1.446215904725317 0.7322704571648098 2.7848636189012677 1.1115539761813293 nan
# k=3 1.0909327884318096 -2.213743040218978 6.386830057566937 -0.3539273524909745 nan
# k=4 1.0109827659798882 -4.944489396143065 10.441831795125161 -1.4918086627547273 nan
# k=5 -0.5357798424747771 -44.54956678521052 68.28332883606711 -18.22055375232999 nan
# k=6 -8.607183109461783 -257.1817487920967 379.3978684383543 -107.90013426170131 nan
# k=7 -1019.230594120754 -24757.356177227877 36097.9095055436 -10553.656566114098 nan
# k=8 -7052130.507482988 -225644607.0447245 335832982.80056417 -95091156.17498359 nan
# k=9 -583767519992099.8 -7019937921611723.0 9336698615723584.0 -3138194801464139.5 nan
# k=10 2.5540682228176216e+30 -3.8730260256876865e+31 6.9124367026789115e+31 -1.446355713465087e+31 nan
# k=11 -1.275332856320638e+62 -9.553802027931968e+62 1.1240291203310013e+63 -4.508281216930927e+62 nan
# ...

# %%
#codeshare line #197-#239
def feval(x):
    y=1*x[0,0]+(-0.6)*x[1,0]+4*x[2,0]+0.25*x[3,0]
    y=y-np.log(x[0,0])-np.log(x[1,0])-np.log(x[2,0])-np.log(x[3,0])
    y=y-np.log(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y
def gfeval(x):
    y=np.array([[0.],[2.],[3.],[4.]])
    y[0,0]=1-1/(x[0,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[1,0]=0-0.6-1/(x[1,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[2,0]=4-1/(x[2,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[3,0]=0.25-1/(x[3,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y

def H(x):
    a=[[1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2]]
    b=[[1/x[0,0]**2,0,0,0],[0,1/x[1,0]**2,0,0],[0,0,1/x[2,0]**2,0],[0,0,0,1/x[3,0]**2]]
    y=np.add(a,b)
    return y

def alp(x,d):
    bar_alpha=float("inf")
    for i in range(4):
        if d[i,0]<0:
            if bar_alpha > -x[i,0]/d[i,0]:
                bar_alpha = -x[i,0]/d[i,0]

    if d[0,0]+d[1,0]+d[2,0]+d[3,0]>0:
        if bar_alpha > (5-(x[0,0]+x[1,0]+x[2,0]+x[3,0]))/(d[0,0]+d[1,0]+d[2,0]+d[3,0]):
            bar_alpha = (5-(x[0,0]+x[1,0]+x[2,0]+x[3,0]))/(d[0,0]+d[1,0]+d[2,0]+d[3,0])
            
    
    a=0
    b=bar_alpha
    alpha = (a+b)/2
    while True:
        if (gfeval(x+alpha*d)).transpose().dot(d)<0:
            a=alpha
            alpha = (a+b)/2
        else:
            b=alpha
            alpha = (a+b)/2
        if abs(a-b) < 0.000001:
            break
    return alpha

iterationNo=[]
iterationX1=[]
iterationX2=[]
iterationX3=[]
iterationX4=[]
iterationX5=[]
iterationX6=[]


x=np.array([[1],[1],[1],[1]]
          )
k=1

r=-gfeval(x)
d=r


while np.sqrt(r.transpose().dot(r)) > 0.000001:
#     print('k=%d' % k,x[0,0],x[1,0],x[2,0],x[3,0],feval(x))
    
    iterationNo.append(k)
    iterationX1.append(x[0,0])
    iterationX2.append(x[1,0])
    iterationX3.append(x[2,0])
    iterationX4.append(x[3,0])
    iterationX5.append(np.sqrt(r.transpose().dot(r))[0,0])
    iterationX6.append(feval(x))

    t=alp(x,d)
    x=x+t*d
    
    r_new=-gfeval(x)
    s=(r_new.transpose().dot(r_new))/(r.transpose().dot(r))
    
    d=r_new+s*d
    r=r_new
    
    k=k+1
    if t==0:
        break
    
#    print('k=%d' % k,x0,x1,d0,d1,norm_d,alpha,feval(x0,x1))#page 32, k=1
  
    
Table={"k":iterationNo,"$x^{0}$":iterationX1,"$x^{1}$":iterationX2,"$x^{2}$":iterationX3,"$x^{3}$":iterationX4,"norm":iterationX5,"feval":iterationX6}
pd.DataFrame(Table)
# Out:
#      k   $x^{0}$   $x^{1}$   $x^{2}$   $x^{3}$      norm     feval
# 0    1  1.000000  1.000000  1.000000  1.000000  4.174027  4.650000
# 1    2  0.802973  1.118216  0.211893  0.950743  1.067425  2.276855
# 2    3  0.498106  2.020289  0.154732  1.185780  1.631517  1.758680
# 3    4  0.476248  2.104841  0.201778  1.196676  0.423621  1.717990
# 4    5  0.526638  2.286217  0.250861  0.946140  1.049877  1.657356
# 5    6  0.549823  2.398122  0.212503  0.780573  0.292336  1.618799
# 6    7  0.545637  2.406746  0.200474  0.776069  0.175679  1.616951
# 7    8  0.515268  2.441268  0.189853  0.790888  0.341378  1.613461
# 8    9  0.487968  2.475921  0.197581  0.808090  0.125951  1.610358
# 9   10  0.488309  2.480747  0.201938  0.810502  0.075554  1.610047
# 10  11  0.495954  2.487972  0.203042  0.813157  0.079439  1.609731
# 11  12  0.499899  2.491126  0.200317  0.813421  0.028937  1.609596
# 12  13  0.500393  2.491529  0.198996  0.811887  0.031143  1.609570
# ...

# %%
#codeshare line #197-#239
def feval(x):
    y=1*x[0,0]+(-0.6)*x[1,0]+4*x[2,0]+0.25*x[3,0]
    y=y-np.log(x[0,0])-np.log(x[1,0])-np.log(x[2,0])-np.log(x[3,0])
    y=y-np.log(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y
def gfeval(x):
    y=np.array([[0.],[2.],[3.],[4.]])
    y[0,0]=1-1/(x[0,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[1,0]=0-0.6-1/(x[1,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[2,0]=4-1/(x[2,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    y[3,0]=0.25-1/(x[3,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
    return y

def H(x):
    a=[[1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2],
        [1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2,1/(5-x.sum())**2]]
    b=[[1/x[0,0]**2,0,0,0],[0,1/x[1,0]**2,0,0],[0,0,1/x[2,0]**2,0],[0,0,0,1/x[3,0]**2]]
    y=np.add(a,b)
    return y

def alp(x,d,r):
    bar_alpha=float("inf")
    for i in range(4):
        if d[i,0]<0:
            if bar_alpha > -x[i,0]/d[i,0]:
                bar_alpha = -x[i,0]/d[i,0]
    
    if d[0,0]+d[1,0]+d[2,0]+d[3,0]>0:
        if bar_alpha > (5-(x[0,0]+x[1,0]+x[2,0]+x[3,0]))/(d[0,0]+d[1,0]+d[2,0]+d[3,0]):
            bar_alpha = (5-(x[0,0]+x[1,0]+x[2,0]+x[3,0]))/(d[0,0]+d[1,0]+d[2,0]+d[3,0])
    
#     print(gfeval(x+bar_alpha*d).transpose().dot(d))

    if gfeval(x+bar_alpha*d).transpose().dot(d)>0:
        a=0
        b=bar_alpha
        alpha = (a+b)/2
        while True:
            if (gfeval(x+alpha*d)).transpose().dot(d)<0:
                a=alpha
                alpha = (a+b)/2
            else:
                b=alpha
                alpha = (a+b)/2
            if abs(a-b) < 0.000001:
                break
    else:
        alpha = (r.transpose().dot(d))/(d.transpose().dot(H(x)).dot(d))
        
    return alpha

iterationNo=[]
iterationX1=[]
iterationX2=[]
iterationX3=[]
iterationX4=[]
iterationX5=[]
iterationX6=[]


x=np.array([[1],[1],[1],[1]])
k=1

r=-gfeval(x)
d=r


while np.sqrt(r.transpose().dot(r)) > 0.000001:
#     print('k=%d' % k,x[0,0],x[1,0],x[2,0],x[3,0],feval(x))
    
    iterationNo.append(k)
    iterationX1.append(x[0,0])
    iterationX2.append(x[1,0])
    iterationX3.append(x[2,0])
    iterationX4.append(x[3,0])
    iterationX5.append(np.sqrt(r.transpose().dot(r))[0,0])
    iterationX6.append(feval(x))

    
    t=alp(x,d,r)
    x=x+t*d
    
    r_new=-gfeval(x)
    s=(r_new.transpose().dot(r_new))/(r.transpose().dot(r))
    
    d=r_new+s*d
    r=r_new
    
    k=k+1
    if t==0:
        break
    
#    print('k=%d' % k,x0,x1,d0,d1,norm_d,alpha,feval(x0,x1))#page 32, k=1
  
    
Table={"k":iterationNo,"$x^{0}$":iterationX1,"$x^{1}$":iterationX2,"$x^{2}$":iterationX3,"$x^{3}$":iterationX4,"norm":iterationX5,"feval":iterationX6}
pd.DataFrame(Table)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10952\1738918632.py:11: RuntimeWarning: divide by zero encountered in double_scalars
#   y[2,0]=4-1/(x[2,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
# C:\Users\User\AppData\Local\Temp\ipykernel_10952\1738918632.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   y[3,0]=0.25-1/(x[3,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
# C:\Users\User\AppData\Local\Temp\ipykernel_10952\1738918632.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   y[0,0]=1-1/(x[0,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
# C:\Users\User\AppData\Local\Temp\ipykernel_10952\1738918632.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   y[1,0]=0-0.6-1/(x[1,0])+1/(5-x[0,0]-x[1,0]-x[2,0]-x[3,0])
#      k   $x^{0}$   $x^{1}$   $x^{2}$   $x^{3}$      norm     feval
# 0    1  1.000000  1.000000  1.000000  1.000000  4.174027  4.650000
# 1    2  0.802973  1.118216  0.211893  0.950743  1.067425  2.276855
# ...
